# %% [markdown]
# # Check out a 1D Gaussian

# %% [markdown]
# Necessary imports:

# %%
import os
import sys 
sys.path.append('..')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import get_field_data as gfd

# %% [markdown]
# Point to the directory, where the data lie.

# %%
# Data path
scratch_dir = "/project/th-scratch/a/And.Lindner"

# Data folder
folder="1d_gaussian"  # 1D simulation on 16 processes

# Combine
path = os.path.join(scratch_dir, folder)
path
# Out:
# '/project/th-scratch/a/And.Lindner/1d_gaussian'

# %% [markdown]
# Note on the data:
# Ttwo Gaussians colliding head-on are simulated.
# The one coming from the left has a larger amplitude and wavelength than the other one in order to mimic a pump-probe-setup.
# The data shows the asymptotic configuration after the collision.

# %% [markdown]
# 1. Define which field component you want to have.
# 0 is $E_x$, 1 is $E_y$, 2 is $E_z$, 3 is $B_x$, etc.
#
# 2. Define which step you want to get.
# The available output steps were defined in the simulation configuration.
#
# 3. Give the number of processes/patches used in the simulation.

# %%
component = 2  # Ez component is third
step = 100  # Step 100 was written to disk
n_prc = 16  # The simulation was running on 16 cores

# %% [markdown]
# Then load it into a variable.

# %%
ez = gfd.get_field1D(path, component, n_prc, step)

# %% [markdown]
# And have a look.

# %%
plt.plot(ez)

# %%
plt.plot(ez[4000:7000])
